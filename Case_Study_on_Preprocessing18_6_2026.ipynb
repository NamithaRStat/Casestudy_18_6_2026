# %% [markdown]
# #Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# importing minmaxscaler
from sklearn.preprocessing import MinMaxScaler

# importing onehot encoder
from sklearn.preprocessing import OneHotEncoder

# importing train_test_split function
from sklearn.model_selection import train_test_split

# %% [markdown]
# # Reading data

# %%
# mounting drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# calling filepath
filepath = '/content/drive/MyDrive/ICT_AIML/data/House_Pricing.csv'

housing_price = pd.read_csv(filepath)
housing_price.head()
# Out:
#            ID Date House was Sold  Sale Price  No of Bedrooms  \
# 0  7129300520     14 October 2017    221900.0               3
# 1  6414100192    14 December 2017    538000.0               3
# 2  5631500400    15 February 2016    180000.0               2
# 3  2487200875    14 December 2017    604000.0               4
# 4  1954400510    15 February 2016    510000.0               3
#
#    No of Bathrooms  Flat Area (in Sqft)  Lot Area (in Sqft)  No of Floors  \
# 0             1.00               1180.0              5650.0           1.0
# 1             2.25               2570.0              7242.0           2.0
# 2             1.00                770.0             10000.0           1.0
# 3             3.00               1960.0              5000.0           1.0
# 4             2.00               1680.0              8080.0           1.0
#
#   Waterfront View No of Times Visited  ... Overall Grade  \
# 0              No                 NaN  ...             7
# 1              No                 NaN  ...             7
# 2              No                 NaN  ...             6
# 3              No                 NaN  ...             7
# 4              No                 NaN  ...             8
#
#    Area of the House from Basement (in Sqft)  Basement Area (in Sqft)  \
# 0                                     1180.0                        0
# 1                                     2170.0                      400
# 2                                      770.0                        0
# 3                                     1050.0                      910
# 4                                     1680.0                        0
#
#    Age of House (in Years)  Renovated Year  Zipcode  Latitude  Longitude  \
# 0                       63               0  98178.0   47.5112   -122.257
# 1                       67            1991  98125.0   47.7210   -122.319
# 2                       85               0  98028.0   47.7379   -122.233
# 3                       53               0  98136.0   47.5208   -122.393
# 4                       31               0  98074.0   47.6168   -122.045
#
#    Living Area after Renovation (in Sqft)  Lot Area after Renovation (in Sqft)
# 0                                  1340.0                                 5650
# 1                                  1690.0                                 7639
# 2                                  2720.0                                 8062
# 3                                  1360.0                                 5000
# 4                                  1800.0                                 7503
#
# [5 rows x 21 columns]

# %% [markdown]
# # EDA

# %%
# Choosing Sale Price as target column. other columns as feature columns

# %%
# checking number of rows and columns
housing_price.shape
# Out:
# (21613, 21)

# %%
# calling details of variables
housing_price.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   ID                                         21613 non-null  int64
#  1   Date House was Sold                        21613 non-null  object
#  2   Sale Price                                 21609 non-null  float64
#  3   No of Bedrooms                             21613 non-null  int64
#  4   No of Bathrooms                            21609 non-null  float64
#  5   Flat Area (in Sqft)                        21604 non-null  float64
#  6   Lot Area (in Sqft)                         21604 non-null  float64
#  7   No of Floors                               21613 non-null  float64
#  8   Waterfront View                            21613 non-null  object
#  9   No of Times Visited                        2124 non-null   object
#  10  Condition of the House                     21613 non-null  object
#  11  Overall Grade                              21613 non-null  int64
#  12  Area of the House from Basement (in Sqft)  21610 non-null  float64
#  13  Basement Area (in Sqft)                    21613 non-null  int64
#  14  Age of House (in Years)                    21613 non-null  int64
#  15  Renovated Year                             21613 non-null  int64
#  16  Zipcode                                    21612 non-null  float64
#  17  Latitude                                   21612 non-null  float64
#  18  Longitude                                  21612 non-null  float64
#  19  Living Area after Renovation (in Sqft)     21612 non-null  float64
#  20  Lot Area after Renovation (in Sqft)        21613 non-null  int64
# dtypes: float64(10), int64(7), object(4)
# memory usage: 3.5+ MB

# %%
# getting summary of numerical variables
housing_price.describe()
# Out:
#                  ID    Sale Price  No of Bedrooms  No of Bathrooms  \
# count  2.161300e+04  2.160900e+04    21613.000000     21609.000000
# mean   4.580302e+09  5.401984e+05        3.370842         2.114732
# std    2.876566e+09  3.673890e+05        0.930062         0.770138
# min    1.000102e+06  7.500000e+04        0.000000         0.000000
# 25%    2.123049e+09  3.219500e+05        3.000000         1.750000
# 50%    3.904930e+09  4.500000e+05        3.000000         2.250000
# 75%    7.308900e+09  6.450000e+05        4.000000         2.500000
# max    9.900000e+09  7.700000e+06       33.000000         8.000000
#
#        Flat Area (in Sqft)  Lot Area (in Sqft)  No of Floors  Overall Grade  \
# count         21604.000000        2.160400e+04  21613.000000   21613.000000
# mean           2079.931772        1.510776e+04      1.494309       7.623467
# std             918.487597        4.142827e+04      0.539989       1.105439
# min             290.000000        5.200000e+02      1.000000       1.000000
# 25%            1429.250000        5.040000e+03      1.000000       7.000000
# 50%            1910.000000        7.617500e+03      1.500000       7.000000
# 75%            2550.000000        1.068825e+04      2.000000       8.000000
# max           13540.000000        1.651359e+06      3.500000      10.000000
#
#        Area of the House from Basement (in Sqft)  Basement Area (in Sqft)  \
# count                               21610.000000             21613.000000
# mean                                 1788.344193               291.509045
# std                                   827.982604               442.575043
# min                                   290.000000                 0.000000
# 25%                                  1190.000000                 0.000000
# 50%                                  1560.000000                 0.000000
# 75%                                  2210.000000               560.000000
# max                                  9410.000000              4820.000000
#
#        Age of House (in Years)  Renovated Year       Zipcode      Latitude  \
# count             21613.000000    21613.000000  21612.000000  21612.000000
# mean                 46.994864       84.402258  98077.937766     47.560048
# std                  29.373411      401.679240     53.505425      0.138565
# min                   3.000000        0.000000  98001.000000     47.155900
# 25%                  21.000000        0.000000  98033.000000     47.470975
# 50%                  43.000000        0.000000  98065.000000     47.571800
# 75%                  67.000000        0.000000  98118.000000     47.678000
# max                 118.000000     2015.000000  98199.000000     47.777600
#
#           Longitude  Living Area after Renovation (in Sqft)  \
# count  21612.000000                            21612.000000
# mean    -122.213892                             1986.538914
# std        0.140830                              685.404255
# min     -122.519000                              399.000000
# 25%     -122.328000                             1490.000000
# 50%     -122.230000                             1840.000000
# 75%     -122.125000                             2360.000000
# max     -121.315000                             6210.000000
#
#        Lot Area after Renovation (in Sqft)
# count                         21613.000000
# mean                          12768.455652
# std                           27304.179631
# min                             651.000000
# 25%                            5100.000000
# 50%                            7620.000000
# 75%                           10083.000000
# max                          871200.000000

# %%
# checking unique values for all columns
for i in housing_price.columns :
  print(housing_price[i].unique)
# Out:
# <bound method Series.unique of 0        7129300520
# 1        6414100192
# 2        5631500400
# 3        2487200875
# 4        1954400510
#             ...
# 21608     263000018
# 21609    6600060120
# 21610    1523300141
# 21611     291310100
# 21612    1523300157
# Name: ID, Length: 21613, dtype: int64>
# <bound method Series.unique of 0         14 October 2017
# 1        14 December 2017
# 2        15 February 2016
# 3        14 December 2017
# 4        15 February 2016
#                ...
# 21608         14 May 2017
# 21609    15 February 2016
# 21610        14 June 2017
# 21611     15 January 2016
# 21612     14 October 2017
# Name: Date House was Sold, Length: 21613, dtype: object>
# <bound method Series.unique of 0        221900.0
# 1        538000.0
# 2        180000.0
# 3        604000.0
# 4        510000.0
#            ...
# 21608    360000.0
# 21609    400000.0
# 21610    402101.0
# 21611    400000.0
# 21612    325000.0
# Name: Sale Price, Length: 21613, dtype: float64>
# <bound method Series.unique of 0        3
# 1        3
# 2        2
# 3        4
# 4        3
#         ..
# 21608    3
# 21609    4
# 21610    2
# 21611    3
# 21612    2
# Name: No of Bedrooms, Length: 21613, dtype: int64>
# <bound method Series.unique of 0        1.00
# 1        2.25
# 2        1.00
# 3        3.00
# 4        2.00
#          ...
# 21608    2.50
# 21609    2.50
# 21610    0.75
# 21611    2.50
# 21612    0.75
# Name: No of Bathrooms, Length: 21613, dtype: float64>
# <bound method Series.unique of 0        1180.0
# 1        2570.0
# 2         770.0
# 3        1960.0
# 4        1680.0
#           ...
# 21608    1530.0
# 21609    2310.0
# 21610    1020.0
# 21611    1600.0
# 21612    1020.0
# Name: Flat Area (in Sqft), Length: 21613, dtype: float64>
# <bound method Series.unique of 0         5650.0
# 1         7242.0
# 2        10000.0
# 3         5000.0
# 4         8080.0
#           ...
# 21608     1131.0
# 21609     5813.0
# 21610     1350.0
# 21611     2388.0
# 21612     1076.0
# Name: Lot Area (in Sqft), Length: 21613, dtype: float64>
# <bound method Series.unique of 0        1.0
# 1        2.0
# 2        1.0
# 3        1.0
# 4        1.0
#         ...
# 21608    3.0
# 21609    2.0
# 21610    2.0
# 21611    2.0
# 21612    2.0
# Name: No of Floors, Length: 21613, dtype: float64>
# <bound method Series.unique of 0        No
# 1        No
# 2        No
# 3        No
# 4        No
#          ..
# 21608    No
# 21609    No
# 21610    No
# 21611    No
# 21612    No
# Name: Waterfront View, Length: 21613, dtype: object>
# <bound method Series.unique of 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN
#         ...
# 21608    NaN
# 21609    NaN
# 21610    NaN
# 21611    NaN
# 21612    NaN
# Name: No of Times Visited, Length: 21613, dtype: object>
# <bound method Series.unique of 0             Fair
# 1             Fair
# 2             Fair
# 3        Excellent
# 4             Fair
#            ...
# 21608         Fair
# 21609         Fair
# 21610         Fair
# 21611         Fair
# 21612         Fair
# Name: Condition of the House, Length: 21613, dtype: object>
# <bound method Series.unique of 0        7
# 1        7
# 2        6
# 3        7
# 4        8
#         ..
# 21608    8
# 21609    8
# 21610    7
# 21611    8
# 21612    7
# Name: Overall Grade, Length: 21613, dtype: int64>
# <bound method Series.unique of 0        1180.0
# 1        2170.0
# 2         770.0
# 3        1050.0
# 4        1680.0
#           ...
# 21608    1530.0
# 21609    2310.0
# 21610    1020.0
# 21611    1600.0
# 21612    1020.0
# Name: Area of the House from Basement (in Sqft), Length: 21613, dtype: float64>
# <bound method Series.unique of 0          0
# 1        400
# 2          0
# 3        910
# 4          0
#         ...
# 21608      0
# 21609      0
# 21610      0
# 21611      0
# 21612      0
# Name: Basement Area (in Sqft), Length: 21613, dtype: int64>
# <bound method Series.unique of 0        63
# 1        67
# 2        85
# 3        53
# 4        31
#          ..
# 21608     9
# 21609     4
# 21610     9
# 21611    14
# 21612    10
# Name: Age of House (in Years), Length: 21613, dtype: int64>
# <bound method Series.unique of 0           0
# 1        1991
# 2           0
# 3           0
# 4           0
#          ...
# 21608       0
# 21609       0
# 21610       0
# 21611       0
# 21612       0
# Name: Renovated Year, Length: 21613, dtype: int64>
# <bound method Series.unique of 0        98178.0
# 1        98125.0
# 2        98028.0
# 3        98136.0
# 4        98074.0
#           ...
# 21608    98103.0
# 21609    98146.0
# 21610    98144.0
# 21611    98027.0
# 21612    98144.0
# Name: Zipcode, Length: 21613, dtype: float64>
# <bound method Series.unique of 0        47.5112
# 1        47.7210
# 2        47.7379
# 3        47.5208
# 4        47.6168
#           ...
# 21608    47.6993
# 21609    47.5107
# 21610    47.5944
# 21611    47.5345
# 21612    47.5941
# Name: Latitude, Length: 21613, dtype: float64>
# <bound method Series.unique of 0       -122.257
# 1       -122.319
# 2       -122.233
# 3       -122.393
# 4       -122.045
#           ...
# 21608   -122.346
# 21609   -122.362
# 21610   -122.299
# 21611   -122.069
# 21612   -122.299
# Name: Longitude, Length: 21613, dtype: float64>
# <bound method Series.unique of 0        1340.0
# 1        1690.0
# 2        2720.0
# 3        1360.0
# 4        1800.0
#           ...
# 21608    1530.0
# 21609    1830.0
# 21610    1020.0
# 21611    1410.0
# 21612    1020.0
# Name: Living Area after Renovation (in Sqft), Length: 21613, dtype: float64>
# <bound method Series.unique of 0        5650
# 1        7639
# 2        8062
# 3        5000
# 4        7503
#          ...
# 21608    1509
# 21609    7200
# 21610    2007
# 21611    1287
# 21612    1357
# Name: Lot Area after Renovation (in Sqft), Length: 21613, dtype: int64>

# %%
# checking value_counts for all columns
for i in housing_price.columns :
  print(housing_price[i].value_counts())
# Out:
# ID
# 795000620     3
# 7520000695    2
# 7200179       2
# 3904100089    2
# 6308000010    2
#              ..
# 5602000275    1
# 1786200010    1
# 1525079069    1
# 126049167     1
# 1211000185    1
# Name: count, Length: 21436, dtype: int64
# Date House was Sold
# 15 April 2016        2231
# 14 July 2017         2211
# 14 June 2017         2180
# 14 August 2017       1940
# 14 October 2017      1878
# 15 March 2016        1875
# 14 September 2017    1774
# 14 May 2017          1768
# 14 December 2017     1471
# 14 November 2017     1411
# 15 February 2016     1250
# 15 January 2016       978
# 15 May 2016           646
# Name: count, dtype: int64
# Sale Price
# 350000.0    172
# 450000.0    171
# 550000.0    159
# 500000.0    152
# 425000.0    150
#            ...
# 357186.0      1
# 747450.0      1
# 589999.0      1
# 402723.0      1
# 999999.0      1
# Name: count, Length: 3625, dtype: int64
# No of Bedrooms
# 3     9824
# 4     6882
# 2     2760
# 5     1601
# 6      272
# 1      199
# 7       38
# 0       13
# 8       13
# 9        6
# 10       3
# 11       1
# 33       1
# Name: count, dtype: int64
# No of Bathrooms
# 2.50    5380
# 1.00    3851
# 1.75    3048
# 2.25    2045
# 2.00    1930
# 1.50    1446
# 2.75    1185
# 3.00     753
# 3.50     730
# 3.25     589
# 3.75     155
# 4.00     136
# 4.50     100
# 4.25      79
# 0.75      72
# 4.75      23
# 5.00      21
# 5.25      13
# 0.00      10
# 5.50      10
# 1.25       9
# 6.00       6
# 0.50       4
# 5.75       4
# 6.75       2
# 8.00       2
# 6.50       2
# 6.25       2
# 7.75       1
# 7.50       1
# Name: count, dtype: int64
# Flat Area (in Sqft)
# 1300.0    138
# 1400.0    135
# 1440.0    133
# 1660.0    129
# 1800.0    129
#          ...
# 2507.0      1
# 9890.0      1
# 5584.0      1
# 1961.0      1
# 5660.0      1
# Name: count, Length: 1036, dtype: int64
# Lot Area (in Sqft)
# 5000.0     357
# 6000.0     290
# 4000.0     251
# 7200.0     220
# 4800.0     120
#           ...
# 2642.0       1
# 2656.0       1
# 15035.0      1
# 638.0        1
# 13405.0      1
# Name: count, Length: 9778, dtype: int64
# No of Floors
# 1.0    10680
# 2.0     8241
# 1.5     1910
# 3.0      613
# 2.5      161
# 3.5        8
# Name: count, dtype: int64
# Waterfront View
# No     21450
# Yes      163
# Name: count, dtype: int64
# No of Times Visited
# Twice     963
# Thrice    510
# Once      332
# Four      319
# Name: count, dtype: int64
# Condition of the House
# Fair         14031
# Good          5679
# Excellent     1701
# Okay           172
# Bad             30
# Name: count, dtype: int64
# Overall Grade
# 7     8981
# 8     6068
# 9     2615
# 6     2038
# 10    1623
# 5      242
# 4       29
# 2       13
# 3        3
# 1        1
# Name: count, dtype: int64
# Area of the House from Basement (in Sqft)
# 1300.0    212
# 1010.0    210
# 1200.0    206
# 1220.0    192
# 1140.0    184
#          ...
# 2244.0      1
# 1606.0      1
# 894.0       1
# 1715.0      1
# 1425.0      1
# Name: count, Length: 946, dtype: int64
# Basement Area (in Sqft)
# 0       13126
# 600       221
# 700       218
# 500       214
# 800       206
#         ...
# 176         1
# 225         1
# 1275        1
# 274         1
# 248         1
# Name: count, Length: 306, dtype: int64
# Age of House (in Years)
# 4      559
# 12     454
# 13     450
# 14     433
# 15     422
#       ...
# 85      30
# 117     29
# 116     27
# 83      24
# 84      21
# Name: count, Length: 116, dtype: int64
# Renovated Year
# 0       20699
# 2014       91
# 2013       37
# 2003       36
# 2005       35
#         ...
# 1948        1
# 1951        1
# 1959        1
# 1934        1
# 1944        1
# Name: count, Length: 70, dtype: int64
# Zipcode
# 98103.0    602
# 98038.0    590
# 98115.0    583
# 98052.0    574
# 98117.0    553
#           ...
# 98102.0    105
# 98010.0    100
# 98024.0     81
# 98148.0     57
# 98039.0     50
# Name: count, Length: 70, dtype: int64
# Latitude
# 47.5491    17
# 47.6624    17
# 47.6846    17
# 47.5322    17
# 47.6711    16
#            ..
# 47.6026     1
# 47.7747     1
# 47.3421     1
# 47.4221     1
# 47.6180     1
# Name: count, Length: 5034, dtype: int64
# Longitude
# -122.290    116
# -122.300    111
# -122.362    104
# -122.291    100
# -122.372     99
#            ...
# -121.316      1
# -121.941      1
# -121.480      1
# -121.767      1
# -122.420      1
# Name: count, Length: 752, dtype: int64
# Living Area after Renovation (in Sqft)
# 1540.0    197
# 1440.0    195
# 1560.0    192
# 1500.0    181
# 1460.0    169
#          ...
# 2513.0      1
# 2725.0      1
# 1955.0      1
# 2527.0      1
# 4443.0      1
# Name: count, Length: 777, dtype: int64
# Lot Area after Renovation (in Sqft)
# 5000    427
# 4000    357
# 6000    289
# 7200    211
# 4800    145
#        ...
# 5259      1
# 3836      1
# 5009      1
# 1395      1
# 5761      1
# Name: count, Length: 8689, dtype: int64

# %%
# Choosing Sale Price as target column.

# %% [markdown]
# # Preprocessing

# %% [markdown]
# ## Checking for duplicates

# %%
housing_price.duplicated().sum()

# no duplicated rows
# Out:
# np.int64(0)

# %% [markdown]
# ## Missing Value Analysis

# %%
housing_price.isna().sum()
# Out:
# ID                                               0
# Date House was Sold                              0
# Sale Price                                       4
# No of Bedrooms                                   0
# No of Bathrooms                                  4
# Flat Area (in Sqft)                              9
# Lot Area (in Sqft)                               9
# No of Floors                                     0
# Waterfront View                                  0
# No of Times Visited                          19489
# Condition of the House                           0
# Overall Grade                                    0
# Area of the House from Basement (in Sqft)        3
# Basement Area (in Sqft)                          0
# Age of House (in Years)                          0
# Renovated Year                                   0
# Zipcode                                          1
# Latitude                                         1
# Longitude                                        1
# Living Area after Renovation (in Sqft)           1
# Lot Area after Renovation (in Sqft)              0
# dtype: int64

# %%
## removing the column 'No of Times Visited' as 90% of the data is missing.
housing_price.drop(['No of Times Visited'],axis=1, inplace = True)

# %%
# droping the rows that have missing values. There is only one missing entry in this columns. So that row removed.
# removing the rows of 'Sale Price' with na as that is the target column.( number of na's  = 4)
housing_price.dropna(subset = ['Zipcode','Latitude','Longitude','Living Area after Renovation (in Sqft)','Sale Price'], inplace = True)

# %%
# checking the updated missing value summary
housing_price.isna().sum()
# Out:
# ID                                           0
# Date House was Sold                          0
# Sale Price                                   0
# No of Bedrooms                               0
# No of Bathrooms                              4
# Flat Area (in Sqft)                          9
# Lot Area (in Sqft)                           9
# No of Floors                                 0
# Waterfront View                              0
# Condition of the House                       0
# Overall Grade                                0
# Area of the House from Basement (in Sqft)    3
# Basement Area (in Sqft)                      0
# Age of House (in Years)                      0
# Renovated Year                               0
# Zipcode                                      0
# Latitude                                     0
# Longitude                                    0
# Living Area after Renovation (in Sqft)       0
# Lot Area after Renovation (in Sqft)          0
# dtype: int64

# %%
sns.histplot(housing_price['Flat Area (in Sqft)'],bins =100)
plt.title("Histogram of Flat Area (in Sqft)")
# Out:
# Text(0.5, 1.0, 'Histogram of Flat Area (in Sqft)')

# %% [markdown]
# Observations from histogram of 'Flat Area (in Sqft)'
#
#
# *   List item The distribution of flat area is right skewed with more smaller values
# *   List item There are two outliers between 11000- 14000?

# %%
sns.histplot(housing_price['No of Bathrooms'],bins =20)
plt.title("Histogram of number of bathrooms")
# Out:
# Text(0.5, 1.0, 'Histogram of number of bathrooms')

# %% [markdown]
# Inferences from histogram of 'number of bathrooms'
#
#
# *   List item The distribution of number of bathrooms is right skewed.

# %%
plt.figure(figsize =(10,10))
sns.histplot(housing_price['Lot Area (in Sqft)'])
plt.title("Histogram of Lot Area (in Sqft)")
# Out:
# Text(0.5, 1.0, 'Histogram of Lot Area (in Sqft)')

# %% [markdown]
# Inferences from histogram of lot area
#
#
# *   List item The distribution of lot area is right skewed.
# *   List item Suspecting outliers around 0.5

# %%
sns.histplot(housing_price['Area of the House from Basement (in Sqft)'],bins = 50)
plt.title("Histogram of Area of the House from Basement(in Sqft)")
# Out:
# Text(0.5, 1.0, 'Histogram of Area of the House from Basement(in Sqft)')

# %% [markdown]
# Inferences from histogram of Area of the House from Basement
#
#
# *   The distribution of Area of the House from Basement(in Sqft) is right skewed.
# *   Suspecting outliers around 8000

# %% [markdown]
# As all columns with missing distributions are skewed to the right, proceeding with calculation of median for replacement.

# %%
housing_price['Flat Area (in Sqft)'].fillna(housing_price['Flat Area (in Sqft)'].median(),inplace = True)
# Out:
# /tmp/ipykernel_949/786315807.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   housing_price['Flat Area (in Sqft)'].fillna(housing_price['Flat Area (in Sqft)'].median(),inplace = True)

# %%
housing_price['Flat Area (in Sqft)'].fillna(housing_price['Flat Area (in Sqft)'].median(),inplace = True)

housing_price['No of Bathrooms'].fillna(housing_price['No of Bathrooms'].median(),inplace = True)

housing_price['Lot Area (in Sqft)'].fillna(housing_price['Lot Area (in Sqft)'].median(),inplace = True)

housing_price['Area of the House from Basement (in Sqft)'].fillna(housing_price['Area of the House from Basement (in Sqft)'].median(),inplace = True)
# Out:
# /tmp/ipykernel_949/4100491377.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   housing_price['Flat Area (in Sqft)'].fillna(housing_price['Flat Area (in Sqft)'].median(),inplace = True)
# /tmp/ipykernel_949/4100491377.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   housing_price['No of Bathrooms'].fillna(housing_price['No of Bathrooms'].median(),inplace = True)
# /tmp/ipykernel_949/4100491377.py:5: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   housing_price['Lot Area (in Sqft)'].fillna(housing_price['Lot Area (in Sqft)'].median(),inplace = True)
# /tmp/ipykernel_949/4100491377.py:7: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   housing_price['Area of the House from Basement (in Sqft)'].fillna(housing_price['Area of the House from Basement (in Sqft)'].median(),inplace = True)

# %%
#housing_price['No of Bathrooms'] = housing_price['No of Bathrooms'].astype(int)

# %%
housing_price.isna().sum()
# Out:
# ID                                           0
# Date House was Sold                          0
# Sale Price                                   0
# No of Bedrooms                               0
# No of Bathrooms                              0
# Flat Area (in Sqft)                          0
# Lot Area (in Sqft)                           0
# No of Floors                                 0
# Waterfront View                              0
# Condition of the House                       0
# Overall Grade                                0
# Area of the House from Basement (in Sqft)    0
# Basement Area (in Sqft)                      0
# Age of House (in Years)                      0
# Renovated Year                               0
# Zipcode                                      0
# Latitude                                     0
# Longitude                                    0
# Living Area after Renovation (in Sqft)       0
# Lot Area after Renovation (in Sqft)          0
# dtype: int64

# %% [markdown]
# ## Outlier Management

# %%
# selecting numericl columns
num_col = housing_price.select_dtypes(include=['int64', 'float64'])
num_col
# Out:
#                ID  Sale Price  No of Bedrooms  No of Bathrooms  \
# 0      7129300520    221900.0               3             1.00
# 1      6414100192    538000.0               3             2.25
# 2      5631500400    180000.0               2             1.00
# 3      2487200875    604000.0               4             3.00
# 4      1954400510    510000.0               3             2.00
# ...           ...         ...             ...              ...
# 21608   263000018    360000.0               3             2.50
# 21609  6600060120    400000.0               4             2.50
# 21610  1523300141    402101.0               2             0.75
# 21611   291310100    400000.0               3             2.50
# 21612  1523300157    325000.0               2             0.75
#
#        Flat Area (in Sqft)  Lot Area (in Sqft)  No of Floors  Overall Grade  \
# 0                   1180.0              5650.0           1.0              7
# 1                   2570.0              7242.0           2.0              7
# 2                    770.0             10000.0           1.0              6
# 3                   1960.0              5000.0           1.0              7
# 4                   1680.0              8080.0           1.0              8
# ...                    ...                 ...           ...            ...
# 21608               1530.0              1131.0           3.0              8
# 21609               2310.0              5813.0           2.0              8
# 21610               1020.0              1350.0           2.0              7
# 21611               1600.0              2388.0           2.0              8
# 21612               1020.0              1076.0           2.0              7
#
#        Area of the House from Basement (in Sqft)  Basement Area (in Sqft)  \
# 0                                         1180.0                        0
# 1                                         2170.0                      400
# 2                                          770.0                        0
# 3                                         1050.0                      910
# 4                                         1680.0                        0
# ...                                          ...                      ...
# 21608                                     1530.0                        0
# 21609                                     2310.0                        0
# 21610                                     1020.0                        0
# 21611                                     1600.0                        0
# 21612                                     1020.0                        0
#
#        Age of House (in Years)  Renovated Year  Zipcode  Latitude  Longitude  \
# 0                           63               0  98178.0   47.5112   -122.257
# 1                           67            1991  98125.0   47.7210   -122.319
# 2                           85               0  98028.0   47.7379   -122.233
# 3                           53               0  98136.0   47.5208   -122.393
# 4                           31               0  98074.0   47.6168   -122.045
# ...                        ...             ...      ...       ...        ...
# 21608                        9               0  98103.0   47.6993   -122.346
# 21609                        4               0  98146.0   47.5107   -122.362
# 21610                        9               0  98144.0   47.5944   -122.299
# 21611                       14               0  98027.0   47.5345   -122.069
# 21612                       10               0  98144.0   47.5941   -122.299
#
#        Living Area after Renovation (in Sqft)  \
# 0                                      1340.0
# 1                                      1690.0
# 2                                      2720.0
# 3                                      1360.0
# 4                                      1800.0
# ...                                       ...
# 21608                                  1530.0
# 21609                                  1830.0
# 21610                                  1020.0
# 21611                                  1410.0
# 21612                                  1020.0
#
#        Lot Area after Renovation (in Sqft)
# 0                                     5650
# 1                                     7639
# 2                                     8062
# 3                                     5000
# 4                                     7503
# ...                                    ...
# 21608                                 1509
# 21609                                 7200
# 21610                                 2007
# 21611                                 1287
# 21612                                 1357
#
# [21605 rows x 17 columns]

# %%
# selecting cat
cat_col = housing_price.select_dtypes(include = ['object','bool'])

# %%
# removing column id for 4x4 subplot format

num_col.drop(columns=['ID'], axis=1,inplace = True)

# %%
num_col.shape
# Out:
# (21605, 16)

# %%
print(num_col)
# Out:
#        Sale Price  No of Bedrooms  No of Bathrooms  Flat Area (in Sqft)  \
# 0        221900.0               3             1.00               1180.0
# 1        538000.0               3             2.25               2570.0
# 2        180000.0               2             1.00                770.0
# 3        604000.0               4             3.00               1960.0
# 4        510000.0               3             2.00               1680.0
# ...           ...             ...              ...                  ...
# 21608    360000.0               3             2.50               1530.0
# 21609    400000.0               4             2.50               2310.0
# 21610    402101.0               2             0.75               1020.0
# 21611    400000.0               3             2.50               1600.0
# 21612    325000.0               2             0.75               1020.0
#
#        Lot Area (in Sqft)  No of Floors  Overall Grade  \
# 0                  5650.0           1.0              7
# 1                  7242.0           2.0              7
# 2                 10000.0           1.0              6
# 3                  5000.0           1.0              7
# 4                  8080.0           1.0              8
# ...                   ...           ...            ...
# 21608              1131.0           3.0              8
# 21609              5813.0           2.0              8
# 21610              1350.0           2.0              7
# 21611              2388.0           2.0              8
# 21612              1076.0           2.0              7
#
#        Area of the House from Basement (in Sqft)  Basement Area (in Sqft)  \
# 0                                         1180.0                        0
# 1                                         2170.0                      400
# 2                                          770.0                        0
# 3                                         1050.0                      910
# 4                                         1680.0                        0
# ...                                          ...                      ...
# 21608                                     1530.0                        0
# 21609                                     2310.0                        0
# 21610                                     1020.0                        0
# 21611                                     1600.0                        0
# 21612                                     1020.0                        0
#
#        Age of House (in Years)  Renovated Year  Zipcode  Latitude  Longitude  \
# 0                           63               0  98178.0   47.5112   -122.257
# 1                           67            1991  98125.0   47.7210   -122.319
# 2                           85               0  98028.0   47.7379   -122.233
# 3                           53               0  98136.0   47.5208   -122.393
# 4                           31               0  98074.0   47.6168   -122.045
# ...                        ...             ...      ...       ...        ...
# 21608                        9               0  98103.0   47.6993   -122.346
# 21609                        4               0  98146.0   47.5107   -122.362
# 21610                        9               0  98144.0   47.5944   -122.299
# 21611                       14               0  98027.0   47.5345   -122.069
# 21612                       10               0  98144.0   47.5941   -122.299
#
#        Living Area after Renovation (in Sqft)  \
# 0                                      1340.0
# 1                                      1690.0
# 2                                      2720.0
# 3                                      1360.0
# 4                                      1800.0
# ...                                       ...
# 21608                                  1530.0
# 21609                                  1830.0
# 21610                                  1020.0
# 21611                                  1410.0
# 21612                                  1020.0
#
#        Lot Area after Renovation (in Sqft)
# 0                                     5650
# 1                                     7639
# 2                                     8062
# 3                                     5000
# 4                                     7503
# ...                                    ...
# 21608                                 1509
# 21609                                 7200
# 21610                                 2007
# 21611                                 1287
# 21612                                 1357
#
# [21605 rows x 16 columns]

# %%
plt.figure(figsize=(12,20))

i= 1
for column in num_col :
  plt.subplot(4,4,i)
  sns.boxplot(num_col[column])
  plt.title(column)
  i += 1

plt.tight_layout()
plt.show()

# %%
num_col.describe()
# checking the descriptive statistics of num_col
# Out:
#          Sale Price  No of Bedrooms  No of Bathrooms  Flat Area (in Sqft)  \
# count  2.160500e+04    21605.000000     21605.000000         21605.000000
# mean   5.402050e+05        3.370840         2.114696          2079.941032
# std    3.674205e+05        0.929939         0.770110           918.393347
# min    7.500000e+04        0.000000         0.000000           290.000000
# 25%    3.215000e+05        3.000000         1.750000          1430.000000
# 50%    4.500000e+05        3.000000         2.250000          1910.000000
# 75%    6.450000e+05        4.000000         2.500000          2550.000000
# max    7.700000e+06       33.000000         8.000000         13540.000000
#
#        Lot Area (in Sqft)  No of Floors  Overall Grade  \
# count        2.160500e+04  21605.000000   21605.000000
# mean         1.510820e+04      1.494237       7.623513
# std          4.142714e+04      0.539927       1.105600
# min          5.200000e+02      1.000000       1.000000
# 25%          5.042000e+03      1.000000       7.000000
# 50%          7.620000e+03      1.500000       7.000000
# 75%          1.068800e+04      2.000000       8.000000
# max          1.651359e+06      3.500000      10.000000
#
#        Area of the House from Basement (in Sqft)  Basement Area (in Sqft)  \
# count                               21605.000000             21605.000000
# mean                                 1788.388243               291.513307
# std                                   827.997287               442.589231
# min                                   290.000000                 0.000000
# 25%                                  1190.000000                 0.000000
# 50%                                  1560.000000                 0.000000
# 75%                                  2210.000000               560.000000
# max                                  9410.000000              4820.000000
#
#        Age of House (in Years)  Renovated Year       Zipcode      Latitude  \
# count             21605.000000    21605.000000  21605.000000  21605.000000
# mean                 46.994214       84.340338  98077.939088     47.560033
# std                  29.367378      401.536399     53.508573      0.138561
# min                   3.000000        0.000000  98001.000000     47.155900
# 25%                  21.000000        0.000000  98033.000000     47.470900
# 50%                  43.000000        0.000000  98065.000000     47.571800
# 75%                  67.000000        0.000000  98118.000000     47.678000
# max                 118.000000     2015.000000  98199.000000     47.777600
#
#           Longitude  Living Area after Renovation (in Sqft)  \
# count  21605.000000                            21605.000000
# mean    -122.213876                             1986.590558
# std        0.140831                              685.475040
# min     -122.519000                              399.000000
# 25%     -122.328000                             1490.000000
# 50%     -122.230000                             1840.000000
# 75%     -122.125000                             2360.000000
# max     -121.315000                             6210.000000
#
#        Lot Area after Renovation (in Sqft)
# count                         21605.000000
# mean                          12771.120065
# std                           27308.853462
# min                             651.000000
# 25%                            5100.000000
# 50%                            7620.000000
# 75%                           10086.000000
# max                          871200.000000

# %%
# Number of bedrooms- 33 is a outlier in the case of number of bedroom as it is a extreme value from the rest of the values. Hence clipping that to second largest number of bedrooms

second_largest  = housing_price['No of Bedrooms'].nlargest(2).iloc[-1] # calculating second largesg value
housing_price['No of Bedrooms'] = housing_price['No of Bedrooms'].clip(upper = second_largest) # clipping by second largest value
sns.boxplot(housing_price['No of Bedrooms'])
# Out:
# <Axes: ylabel='No of Bedrooms'>

# %%
#In Flat Area (in Sqft), there is only two columns which are outliers. Hence clipping the two highest observations to 3rd lrgest observation

third_large_flat  = housing_price['Flat Area (in Sqft)'].nlargest(3).iloc[-2] # calculating third largest value of Flat Area (in Sqft)
housing_price['Flat Area (in Sqft)'] = housing_price['Flat Area (in Sqft)'].clip(upper = third_large_flat) # clipping by third largest value
sns.boxplot(housing_price['Flat Area (in Sqft)'])
# Out:
# <Axes: ylabel='Flat Area (in Sqft)'>

# %% [markdown]
# In other features, the variables are having right skewed distribution, hence the extreme positive values are indicating propoerties of the variable. Hence they are not removed.

# %% [markdown]
# # Scaling

# %%
num_col['Renovated Year'].value_counts()
# Out:
# Renovated Year
# 0       20692
# 2014       91
# 2013       36
# 2003       36
# 2005       35
#         ...
# 1948        1
# 1951        1
# 1959        1
# 1934        1
# 1944        1
# Name: count, Length: 70, dtype: int64

# %% [markdown]
# # Scaling

# %%
num_col.columns #checking col names of num_col
# Out:
# Index(['Sale Price', 'No of Bedrooms', 'No of Bathrooms',
#        'Flat Area (in Sqft)', 'Lot Area (in Sqft)', 'No of Floors',
#        'Overall Grade', 'Area of the House from Basement (in Sqft)',
#        'Basement Area (in Sqft)', 'Age of House (in Years)', 'Renovated Year',
#        'Zipcode', 'Latitude', 'Longitude',
#        'Living Area after Renovation (in Sqft)',
#        'Lot Area after Renovation (in Sqft)'],
#       dtype='object')

# %%
num_col = num_col.drop(['Renovated Year','Overall Grade'], axis=1) # removing 'Renovated Year' as it is categorical

num_col2 = num_col.drop(['Zipcode', 'Latitude', 'Longitude'], axis=1) # this columns are not suitable for scaling, as these are identifiers
                 #<-The numerical columns
num_col2.shape
# Out:
# (21605, 11)

# %%
plt.figure(figsize=(15,20))

i= 1
for column in num_col2 :
  plt.subplot(11,1,i)
  sns.histplot(num_col2[column],kde = True)
  plt.title(column)
  i += 1

plt.tight_layout()
plt.show()

# %% [markdown]
# All columns are right skewed, hence applying minmax scaler for all numerical columns.

# %%
minmaxscaler = MinMaxScaler() # creating an object

housing_price[num_col.columns] = minmaxscaler.fit_transform(housing_price[num_col.columns]) # transforming numerical columns

# %% [markdown]
# # Encoding

# %%
cat_col = housing_price.drop(columns = num_col.columns) # taking all columns which are not numerical
cat_col = cat_col.drop(['ID','Date House was Sold'],axis =1) # dropping the column of ID as it is an identifier and 'Date House was Sold' as it doesnt need encoding

# %%
cat_col.columns # checking the names of categorical columns

# all columns are non- binary. Hnece proceeding with one hot encoding
# Out:
# Index(['Waterfront View', 'Condition of the House', 'Overall Grade',
#        'Renovated Year'],
#       dtype='object')

# %%
housing_price = pd.get_dummies(housing_price, columns = cat_col.columns ,dtype = int)
housing_price
# Out:
#                ID Date House was Sold  Sale Price  No of Bedrooms  \
# 0      7129300520     14 October 2017    0.019266        0.272727
# 1      6414100192    14 December 2017    0.060721        0.272727
# 2      5631500400    15 February 2016    0.013770        0.181818
# 3      2487200875    14 December 2017    0.069377        0.363636
# 4      1954400510    15 February 2016    0.057049        0.272727
# ...           ...                 ...         ...             ...
# 21608   263000018         14 May 2017    0.037377        0.272727
# 21609  6600060120    15 February 2016    0.042623        0.363636
# 21610  1523300141        14 June 2017    0.042898        0.181818
# 21611   291310100     15 January 2016    0.042623        0.272727
# 21612  1523300157     14 October 2017    0.032787        0.181818
#
#        No of Bathrooms  Flat Area (in Sqft)  Lot Area (in Sqft)  No of Floors  \
# 0              0.12500             0.075680            0.003108           0.0
# 1              0.28125             0.193878            0.004072           0.4
# 2              0.12500             0.040816            0.005743           0.0
# 3              0.37500             0.142007            0.002714           0.0
# 4              0.25000             0.118197            0.004579           0.0
# ...                ...                  ...                 ...           ...
# 21608          0.31250             0.105442            0.000370           0.8
# 21609          0.31250             0.171769            0.003206           0.4
# 21610          0.09375             0.062075            0.000503           0.4
# 21611          0.31250             0.111395            0.001132           0.4
# 21612          0.09375             0.062075            0.000337           0.4
#
#        Area of the House from Basement (in Sqft)  Basement Area (in Sqft)  \
# 0                                       0.097588                 0.000000
# 1                                       0.206140                 0.082988
# 2                                       0.052632                 0.000000
# 3                                       0.083333                 0.188797
# 4                                       0.152412                 0.000000
# ...                                          ...                      ...
# 21608                                   0.135965                 0.000000
# 21609                                   0.221491                 0.000000
# 21610                                   0.080044                 0.000000
# 21611                                   0.143640                 0.000000
# 21612                                   0.080044                 0.000000
#
#        ...  Renovated Year_2006  Renovated Year_2007  Renovated Year_2008  \
# 0      ...                    0                    0                    0
# 1      ...                    0                    0                    0
# 2      ...                    0                    0                    0
# 3      ...                    0                    0                    0
# 4      ...                    0                    0                    0
# ...    ...                  ...                  ...                  ...
# 21608  ...                    0                    0                    0
# 21609  ...                    0                    0                    0
# 21610  ...                    0                    0                    0
# 21611  ...                    0                    0                    0
# 21612  ...                    0                    0                    0
#
#        Renovated Year_2009  Renovated Year_2010  Renovated Year_2011  \
# 0                        0                    0                    0
# 1                        0                    0                    0
# 2                        0                    0                    0
# 3                        0                    0                    0
# 4                        0                    0                    0
# ...                    ...                  ...                  ...
# 21608                    0                    0                    0
# 21609                    0                    0                    0
# 21610                    0                    0                    0
# 21611                    0                    0                    0
# 21612                    0                    0                    0
#
#        Renovated Year_2012  Renovated Year_2013  Renovated Year_2014  \
# 0                        0                    0                    0
# 1                        0                    0                    0
# 2                        0                    0                    0
# 3                        0                    0                    0
# 4                        0                    0                    0
# ...                    ...                  ...                  ...
# 21608                    0                    0                    0
# 21609                    0                    0                    0
# 21610                    0                    0                    0
# 21611                    0                    0                    0
# 21612                    0                    0                    0
#
#        Renovated Year_2015
# 0                        0
# 1                        0
# 2                        0
# 3                        0
# 4                        0
# ...                    ...
# 21608                    0
# 21609                    0
# 21610                    0
# 21611                    0
# 21612                    0
#
# [21605 rows x 103 columns]

# %% [markdown]
# # Train-Test Split

# %%
#housing_price.columns.tolist()
y = housing_price['Sale Price'] # defining target column
X = housing_price.drop(columns = ['Sale Price']) # defining deture columns

X_train, X_test, y_train, y_test = train_test_split(
    X, y,
    test_size=0.20,
    random_state=42
)
